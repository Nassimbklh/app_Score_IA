# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime
import pickle
import joblib
import csv

# %%
# Charger les données
data = pd.read_csv('Données/dataset.csv')
team_dict = pd.read_csv('Données/team_dict.csv')
#match = pd.read_csv('Données/predicted_Chelsea_Arsenal_20240628.csv')

# Remplir les valeurs manquantes avec 0 (si nécessaire)
#data.fillna(0, inplace=True)

# Charger les modèles
random_forest = joblib.load('Modèles/Random_forest.sav')

with open('Modèles/models.pkl', 'rb') as file:
    linear_models = pickle.load(file)

with open('Modèles/scalers.pkl', 'rb') as file:
    linear_scalers = pickle.load(file)
# Out:
# c:\Users\sweez\anaconda3\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.4.2 when using version 1.5.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\sweez\anaconda3\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.4.2 when using version 1.5.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\sweez\anaconda3\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LinearRegression from version 1.3.0 when using version 1.5.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\sweez\anaconda3\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.3.0 when using version 1.5.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
team_ids = team_dict.set_index('Team')['ID'].to_dict()

# %%
# Sélectionner les fonctionnalités d'apprentissage du modèle
features = ['FTHG', 'FTAG', 'HTGS', 'ATGS', 'HTGC'
            , 'ATGC', 'HTP', 'ATP', 'MW', 'HTFormPts', 'ATFormPts'
            , 'HTWinStreak3', 'HTWinStreak5', 'HTLossStreak3', 'HTLossStreak5'
            , 'ATWinStreak3', 'ATWinStreak5', 'ATLossStreak3', 'ATLossStreak5'
            , 'HTGD', 'ATGD', 'DiffPts', 'DiffFormPts']

# %%
# Saisir l'équipe à domicile et l'équipe à l'extérieur
home_team = input("Enter the Home Team: ")
away_team = input("Enter the Away Team: ")

# %%
# Filtrer les données pour les équipes spécifiques
filtered_data = data.loc[np.where((data['HomeTeam'] == home_team) | (data['AwayTeam'] == away_team))] #data.loc[np.where((data['HomeTeam'] == home_team) | (data['AwayTeam'] == away_team))]
filtered_data.shape
# Out:
# (666, 40)

# %%
if not filtered_data.empty:

    # Filtrer uniquement les colonnes numériques pour le calcul de la moyenne
    combined_data_numeric = filtered_data[features].mean(axis=0)

    # Créer une DataFrame temporaire pour contenir les valeurs moyennes des caractéristiques / .T transpose la matrice pour obtenir une ligne unique de valeurs moyennes
    combined_data_df = pd.DataFrame(combined_data_numeric).T

    predicted_features = {}
    for feature in features:
        combined_data_scaled = linear_scalers[feature].transform(combined_data_df.drop(columns=[feature]))
        predicted_features[feature] = linear_models[feature].predict(combined_data_scaled)[0]

    # Créer un DataFrame avec les résultats
    results = pd.DataFrame({
        'HomeTeam': [home_team],
        'AwayTeam': [away_team],
        'FTHG': [predicted_features['FTHG']],
        'FTAG': [predicted_features['FTAG']],
        'FTR': [np.nan],  # La colonne FTR est initialisée avec NaN pour être prédite ensuite
        'HTGS': [predicted_features['HTGS']],
        'ATGS': [predicted_features['ATGS']],
        'HTGC': [predicted_features['HTGC']],
        'ATGC': [predicted_features['ATGC']],
        'HTP': [predicted_features['HTP']],
        'ATP': [predicted_features['ATP']],
        'MW': [predicted_features['MW']],
        'HTFormPts': [predicted_features['HTFormPts']],
        'ATFormPts': [predicted_features['ATFormPts']],
        'HTWinStreak3': [predicted_features['HTWinStreak3']],
        'HTWinStreak5': [predicted_features['HTWinStreak5']],
        'HTLossStreak3': [predicted_features['HTLossStreak3']],
        'HTLossStreak5': [predicted_features['HTLossStreak5']],
        'ATWinStreak3': [predicted_features['ATWinStreak3']],
        'ATWinStreak5': [predicted_features['ATWinStreak5']],
        'ATLossStreak3': [predicted_features['ATLossStreak3']],
        'ATLossStreak5': [predicted_features['ATLossStreak5']],
        'HTGD': [predicted_features['HTGD']],
        'ATGD': [predicted_features['ATGD']],
        'DiffPts': [predicted_features['DiffPts']],
        'DiffFormPts': [predicted_features['DiffFormPts']]
    })

    # Enregistrer les résultats dans un fichier CSV avec date et noms d'équipe
    current_date = datetime.now().strftime("%Y%m%d")

    # Spécifier le chemin où vous souhaitez enregistrer le fichier CSV
    output_path = 'Prédictions à prédire'
    file_name = f'predicted_{home_team}_{away_team}_{current_date}.csv'
    file_path = os.path.join(output_path, file_name)

    results.to_csv(file_path, index=False)
    print(f"Les prédictions du match sont stockées dans 'predicted_{home_team}_{away_team}_{current_date}.csv'")
    
else:
    print("Les données pour les équipes spécifiées ne sont pas disponibles dans le dataset.")
# Out:
# Les prédictions du match sont stockées dans 'predicted_Arsenal_Chelsea_20240628.csv'

# %%
def encoding_teams(df):
    # Convertir les noms d'équipe en IDs en utilisant le dictionnaire team_ids
    df['HomeTeam'] = df['HomeTeam'].replace(team_ids).astype('int32')
    df['AwayTeam'] = df['AwayTeam'].replace(team_ids).astype('int32')

    return df

# %%
# Mettre des ids aux équipes
datatest = encoding_teams(results)

# %%
X_test = datatest[['HomeTeam', 'AwayTeam'] + features]
y_test = datatest['FTR']

# %%
# Prédire si l'équipe à domicile gagne ou non
predicted_results = random_forest.predict(X_test)

# Afficher le nom des équipes prédites et le résultat de la prédiction
for i, (home_team_id, away_team_id, prediction) in enumerate(zip(X_test['HomeTeam'], X_test['AwayTeam'], predicted_results)):
    home_team_name = list(team_ids.keys())[list(team_ids.values()).index(home_team_id)]
    away_team_name = list(team_ids.keys())[list(team_ids.values()).index(away_team_id)]
    
    if prediction == 1:
        # Afficher le nom des équipes prédites et le résultat de la prédiction
        print(f"Match: {home_team_name} vs {away_team_name}, Prediction: {home_team_name} gagne")

    if prediction == 0:
        # Afficher le nom des équipes prédites et le résultat de la prédiction
        print(f"Match: {home_team_name} vs {away_team_name}, Prediction: {home_team_name} égalise ou perd")

print(predicted_results)
# Out:
# Match: Arsenal vs Chelsea, Prediction: Arsenal gagne
# [1]

# %%
# Chemin du fichier CSV pour stocker les résultats
output_results_path = 'predicted_match_results_test.csv'

# Ouvrir le fichier en mode 'a' pour ajouter des lignes sans écraser le contenu existant
with open(output_results_path, mode='a', newline='') as file:
    writer = csv.writer(file)
    
    # Écrire l'en-tête si le fichier est vide (ou à une autre condition, comme vérifier le contenu)
    if file.tell() == 0:
        writer.writerow(['HomeTeam', 'AwayTeam', 'Prediction'])
    else:
        writer.writerow([home_team, away_team, predicted_results[0]])

# %%
teams = ["Man City", "Arsenal", "Liverpool", "Aston Villa", "Tottenham", 
         "Chelsea", "Newcastle", "Man United", "West Ham", "Crystal Palace", 
         "Brighton", "Bournemouth", "Fulham", "Wolves", "Everton", 
         "Brentford", "Nottm Forrest", "Luton Town", "Burnley", "Sheffield United"]

# Liste pour stocker toutes les combinaisons de matchs
match_combinations = []

# Parcours de chaque équipe pour créer les paires de matchs
for i in range(len(teams)):
    home_team = teams[i]
    for j in range(len(teams)):
        if i != j:  # Éviter les matchs d'une équipe contre elle-même
            away_team = teams[j]
            match_combinations.append((home_team, away_team))

# Affichage des résultats
for idx, match in enumerate(match_combinations):
    print(f"Match {idx+1}: {match[0]} vs {match[1]}")
# Out:
# Match 1: Man City vs Arsenal
# Match 2: Man City vs Liverpool
# Match 3: Man City vs Aston Villa
# Match 4: Man City vs Tottenham
# Match 5: Man City vs Chelsea
# Match 6: Man City vs Newcastle
# Match 7: Man City vs Man United
# Match 8: Man City vs West Ham
# Match 9: Man City vs Crystal Palace
# Match 10: Man City vs Brighton
# Match 11: Man City vs Bournemouth
# Match 12: Man City vs Fulham
# Match 13: Man City vs Wolves
# Match 14: Man City vs Everton
# Match 15: Man City vs Brentford
# Match 16: Man City vs Nottm Forrest
# Match 17: Man City vs Luton Town
# Match 18: Man City vs Burnley
# Match 19: Man City vs Sheffield United
# Match 20: Arsenal vs Man City
# Match 21: Arsenal vs Liverpool
# Match 22: Arsenal vs Aston Villa
# Match 23: Arsenal vs Tottenham
# Match 24: Arsenal vs Chelsea
# Match 25: Arsenal vs Newcastle
# Match 26: Arsenal vs Man United
# Match 27: Arsenal vs West Ham
# Match 28: Arsenal vs Crystal Palace
# Match 29: Arsenal vs Brighton
# Match 30: Arsenal vs Bournemouth
# Match 31: Arsenal vs Fulham
# Match 32: Arsenal vs Wolves
# Match 33: Arsenal vs Everton
# Match 34: Arsenal vs Brentford
# Match 35: Arsenal vs Nottm Forrest
# Match 36: Arsenal vs Luton Town
# Match 37: Arsenal vs Burnley
# Match 38: Arsenal vs Sheffield United
# Match 39: Liverpool vs Man City
# Match 40: Liverpool vs Arsenal
# Match 41: Liverpool vs Aston Villa
# Match 42: Liverpool vs Tottenham
# Match 43: Liverpool vs Chelsea
# Match 44: Liverpool vs Newcastle
# Match 45: Liverpool vs Man United
# Match 46: Liverpool vs West Ham
# Match 47: Liverpool vs Crystal Palace
# Match 48: Liverpool vs Brighton
# Match 49: Liverpool vs Bournemouth
# Match 50: Liverpool vs Fulham
# Match 51: Liverpool vs Wolves
# Match 52: Liverpool vs Everton
# Match 53: Liverpool vs Brentford
# Match 54: Liverpool vs Nottm Forrest
# Match 55: Liverpool vs Luton Town
# Match 56: Liverpool vs Burnley
# Match 57: Liverpool vs Sheffield United
# Match 58: Aston Villa vs Man City
# Match 59: Aston Villa vs Arsenal
# Match 60: Aston Villa vs Liverpool
# Match 61: Aston Villa vs Tottenham
# Match 62: Aston Villa vs Chelsea
# Match 63: Aston Villa vs Newcastle
# Match 64: Aston Villa vs Man United
# Match 65: Aston Villa vs West Ham
# Match 66: Aston Villa vs Crystal Palace
# Match 67: Aston Villa vs Brighton
# Match 68: Aston Villa vs Bournemouth
# Match 69: Aston Villa vs Fulham
# Match 70: Aston Villa vs Wolves
# Match 71: Aston Villa vs Everton
# Match 72: Aston Villa vs Brentford
# Match 73: Aston Villa vs Nottm Forrest
# Match 74: Aston Villa vs Luton Town
# Match 75: Aston Villa vs Burnley
# Match 76: Aston Villa vs Sheffield United
# Match 77: Tottenham vs Man City
# Match 78: Tottenham vs Arsenal
# Match 79: Tottenham vs Liverpool
# Match 80: Tottenham vs Aston Villa
# Match 81: Tottenham vs Chelsea
# Match 82: Tottenham vs Newcastle
# Match 83: Tottenham vs Man United
# Match 84: Tottenham vs West Ham
# Match 85: Tottenham vs Crystal Palace
# Match 86: Tottenham vs Brighton
# Match 87: Tottenham vs Bournemouth
# Match 88: Tottenham vs Fulham
# Match 89: Tottenham vs Wolves
# Match 90: Tottenham vs Everton
# Match 91: Tottenham vs Brentford
# Match 92: Tottenham vs Nottm Forrest
# Match 93: Tottenham vs Luton Town
# Match 94: Tottenham vs Burnley
# Match 95: Tottenham vs Sheffield United
# Match 96: Chelsea vs Man City
# Match 97: Chelsea vs Arsenal
# Match 98: Chelsea vs Liverpool
# Match 99: Chelsea vs Aston Villa
# Match 100: Chelsea vs Tottenham
# Match 101: Chelsea vs Newcastle
# Match 102: Chelsea vs Man United
# Match 103: Chelsea vs West Ham
# Match 104: Chelsea vs Crystal Palace
# Match 105: Chelsea vs Brighton
# Match 106: Chelsea vs Bournemouth
# Match 107: Chelsea vs Fulham
# Match 108: Chelsea vs Wolves
# Match 109: Chelsea vs Everton
# Match 110: Chelsea vs Brentford
# Match 111: Chelsea vs Nottm Forrest
# Match 112: Chelsea vs Luton Town
# Match 113: Chelsea vs Burnley
# Match 114: Chelsea vs Sheffield United
# Match 115: Newcastle vs Man City
# Match 116: Newcastle vs Arsenal
# Match 117: Newcastle vs Liverpool
# Match 118: Newcastle vs Aston Villa
# Match 119: Newcastle vs Tottenham
# Match 120: Newcastle vs Chelsea
# Match 121: Newcastle vs Man United
# Match 122: Newcastle vs West Ham
# Match 123: Newcastle vs Crystal Palace
# Match 124: Newcastle vs Brighton
# Match 125: Newcastle vs Bournemouth
# Match 126: Newcastle vs Fulham
# Match 127: Newcastle vs Wolves
# Match 128: Newcastle vs Everton
# Match 129: Newcastle vs Brentford
# Match 130: Newcastle vs Nottm Forrest
# Match 131: Newcastle vs Luton Town
# Match 132: Newcastle vs Burnley
# Match 133: Newcastle vs Sheffield United
# Match 134: Man United vs Man City
# Match 135: Man United vs Arsenal
# Match 136: Man United vs Liverpool
# Match 137: Man United vs Aston Villa
# Match 138: Man United vs Tottenham
# Match 139: Man United vs Chelsea
# Match 140: Man United vs Newcastle
# Match 141: Man United vs West Ham
# Match 142: Man United vs Crystal Palace
# Match 143: Man United vs Brighton
# Match 144: Man United vs Bournemouth
# Match 145: Man United vs Fulham
# Match 146: Man United vs Wolves
# Match 147: Man United vs Everton
# Match 148: Man United vs Brentford
# Match 149: Man United vs Nottm Forrest
# Match 150: Man United vs Luton Town
# Match 151: Man United vs Burnley
# Match 152: Man United vs Sheffield United
# Match 153: West Ham vs Man City
# Match 154: West Ham vs Arsenal
# Match 155: West Ham vs Liverpool
# Match 156: West Ham vs Aston Villa
# Match 157: West Ham vs Tottenham
# Match 158: West Ham vs Chelsea
# Match 159: West Ham vs Newcastle
# Match 160: West Ham vs Man United
# Match 161: West Ham vs Crystal Palace
# Match 162: West Ham vs Brighton
# Match 163: West Ham vs Bournemouth
# Match 164: West Ham vs Fulham
# Match 165: West Ham vs Wolves
# Match 166: West Ham vs Everton
# Match 167: West Ham vs Brentford
# Match 168: West Ham vs Nottm Forrest
# Match 169: West Ham vs Luton Town
# Match 170: West Ham vs Burnley
# Match 171: West Ham vs Sheffield United
# Match 172: Crystal Palace vs Man City
# Match 173: Crystal Palace vs Arsenal
# Match 174: Crystal Palace vs Liverpool
# Match 175: Crystal Palace vs Aston Villa
# Match 176: Crystal Palace vs Tottenham
# Match 177: Crystal Palace vs Chelsea
# Match 178: Crystal Palace vs Newcastle
# Match 179: Crystal Palace vs Man United
# Match 180: Crystal Palace vs West Ham
# Match 181: Crystal Palace vs Brighton
# Match 182: Crystal Palace vs Bournemouth
# Match 183: Crystal Palace vs Fulham
# Match 184: Crystal Palace vs Wolves
# Match 185: Crystal Palace vs Everton
# Match 186: Crystal Palace vs Brentford
# Match 187: Crystal Palace vs Nottm Forrest
# Match 188: Crystal Palace vs Luton Town
# Match 189: Crystal Palace vs Burnley
# Match 190: Crystal Palace vs Sheffield United
# Match 191: Brighton vs Man City
# Match 192: Brighton vs Arsenal
# Match 193: Brighton vs Liverpool
# Match 194: Brighton vs Aston Villa
# Match 195: Brighton vs Tottenham
# Match 196: Brighton vs Chelsea
# Match 197: Brighton vs Newcastle
# Match 198: Brighton vs Man United
# Match 199: Brighton vs West Ham
# Match 200: Brighton vs Crystal Palace
# Match 201: Brighton vs Bournemouth
# Match 202: Brighton vs Fulham
# Match 203: Brighton vs Wolves
# Match 204: Brighton vs Everton
# Match 205: Brighton vs Brentford
# Match 206: Brighton vs Nottm Forrest
# Match 207: Brighton vs Luton Town
# Match 208: Brighton vs Burnley
# Match 209: Brighton vs Sheffield United
# Match 210: Bournemouth vs Man City
# Match 211: Bournemouth vs Arsenal
# Match 212: Bournemouth vs Liverpool
# Match 213: Bournemouth vs Aston Villa
# Match 214: Bournemouth vs Tottenham
# Match 215: Bournemouth vs Chelsea
# Match 216: Bournemouth vs Newcastle
# Match 217: Bournemouth vs Man United
# Match 218: Bournemouth vs West Ham
# Match 219: Bournemouth vs Crystal Palace
# Match 220: Bournemouth vs Brighton
# Match 221: Bournemouth vs Fulham
# Match 222: Bournemouth vs Wolves
# Match 223: Bournemouth vs Everton
# Match 224: Bournemouth vs Brentford
# Match 225: Bournemouth vs Nottm Forrest
# Match 226: Bournemouth vs Luton Town
# Match 227: Bournemouth vs Burnley
# Match 228: Bournemouth vs Sheffield United
# Match 229: Fulham vs Man City
# Match 230: Fulham vs Arsenal
# Match 231: Fulham vs Liverpool
# Match 232: Fulham vs Aston Villa
# Match 233: Fulham vs Tottenham
# Match 234: Fulham vs Chelsea
# Match 235: Fulham vs Newcastle
# Match 236: Fulham vs Man United
# Match 237: Fulham vs West Ham
# Match 238: Fulham vs Crystal Palace
# Match 239: Fulham vs Brighton
# Match 240: Fulham vs Bournemouth
# Match 241: Fulham vs Wolves
# Match 242: Fulham vs Everton
# Match 243: Fulham vs Brentford
# Match 244: Fulham vs Nottm Forrest
# Match 245: Fulham vs Luton Town
# Match 246: Fulham vs Burnley
# Match 247: Fulham vs Sheffield United
# Match 248: Wolves vs Man City
# Match 249: Wolves vs Arsenal
# Match 250: Wolves vs Liverpool
# Match 251: Wolves vs Aston Villa
# Match 252: Wolves vs Tottenham
# Match 253: Wolves vs Chelsea
# Match 254: Wolves vs Newcastle
# Match 255: Wolves vs Man United
# Match 256: Wolves vs West Ham
# Match 257: Wolves vs Crystal Palace
# Match 258: Wolves vs Brighton
# Match 259: Wolves vs Bournemouth
# Match 260: Wolves vs Fulham
# Match 261: Wolves vs Everton
# Match 262: Wolves vs Brentford
# Match 263: Wolves vs Nottm Forrest
# Match 264: Wolves vs Luton Town
# Match 265: Wolves vs Burnley
# Match 266: Wolves vs Sheffield United
# Match 267: Everton vs Man City
# Match 268: Everton vs Arsenal
# Match 269: Everton vs Liverpool
# Match 270: Everton vs Aston Villa
# Match 271: Everton vs Tottenham
# Match 272: Everton vs Chelsea
# Match 273: Everton vs Newcastle
# Match 274: Everton vs Man United
# Match 275: Everton vs West Ham
# Match 276: Everton vs Crystal Palace
# Match 277: Everton vs Brighton
# Match 278: Everton vs Bournemouth
# Match 279: Everton vs Fulham
# Match 280: Everton vs Wolves
# Match 281: Everton vs Brentford
# Match 282: Everton vs Nottm Forrest
# Match 283: Everton vs Luton Town
# Match 284: Everton vs Burnley
# Match 285: Everton vs Sheffield United
# Match 286: Brentford vs Man City
# Match 287: Brentford vs Arsenal
# Match 288: Brentford vs Liverpool
# Match 289: Brentford vs Aston Villa
# Match 290: Brentford vs Tottenham
# Match 291: Brentford vs Chelsea
# Match 292: Brentford vs Newcastle
# Match 293: Brentford vs Man United
# Match 294: Brentford vs West Ham
# Match 295: Brentford vs Crystal Palace
# Match 296: Brentford vs Brighton
# Match 297: Brentford vs Bournemouth
# Match 298: Brentford vs Fulham
# Match 299: Brentford vs Wolves
# Match 300: Brentford vs Everton
# Match 301: Brentford vs Nottm Forrest
# Match 302: Brentford vs Luton Town
# Match 303: Brentford vs Burnley
# Match 304: Brentford vs Sheffield United
# Match 305: Nottm Forrest vs Man City
# Match 306: Nottm Forrest vs Arsenal
# Match 307: Nottm Forrest vs Liverpool
# Match 308: Nottm Forrest vs Aston Villa
# Match 309: Nottm Forrest vs Tottenham
# Match 310: Nottm Forrest vs Chelsea
# Match 311: Nottm Forrest vs Newcastle
# Match 312: Nottm Forrest vs Man United
# Match 313: Nottm Forrest vs West Ham
# Match 314: Nottm Forrest vs Crystal Palace
# Match 315: Nottm Forrest vs Brighton
# Match 316: Nottm Forrest vs Bournemouth
# Match 317: Nottm Forrest vs Fulham
# Match 318: Nottm Forrest vs Wolves
# Match 319: Nottm Forrest vs Everton
# Match 320: Nottm Forrest vs Brentford
# Match 321: Nottm Forrest vs Luton Town
# Match 322: Nottm Forrest vs Burnley
# Match 323: Nottm Forrest vs Sheffield United
# Match 324: Luton Town vs Man City
# Match 325: Luton Town vs Arsenal
# Match 326: Luton Town vs Liverpool
# Match 327: Luton Town vs Aston Villa
# Match 328: Luton Town vs Tottenham
# Match 329: Luton Town vs Chelsea
# Match 330: Luton Town vs Newcastle
# Match 331: Luton Town vs Man United
# Match 332: Luton Town vs West Ham
# Match 333: Luton Town vs Crystal Palace
# Match 334: Luton Town vs Brighton
# Match 335: Luton Town vs Bournemouth
# Match 336: Luton Town vs Fulham
# Match 337: Luton Town vs Wolves
# Match 338: Luton Town vs Everton
# Match 339: Luton Town vs Brentford
# Match 340: Luton Town vs Nottm Forrest
# Match 341: Luton Town vs Burnley
# Match 342: Luton Town vs Sheffield United
# Match 343: Burnley vs Man City
# Match 344: Burnley vs Arsenal
# Match 345: Burnley vs Liverpool
# Match 346: Burnley vs Aston Villa
# Match 347: Burnley vs Tottenham
# Match 348: Burnley vs Chelsea
# Match 349: Burnley vs Newcastle
# Match 350: Burnley vs Man United
# Match 351: Burnley vs West Ham
# Match 352: Burnley vs Crystal Palace
# Match 353: Burnley vs Brighton
# Match 354: Burnley vs Bournemouth
# Match 355: Burnley vs Fulham
# Match 356: Burnley vs Wolves
# Match 357: Burnley vs Everton
# Match 358: Burnley vs Brentford
# Match 359: Burnley vs Nottm Forrest
# Match 360: Burnley vs Luton Town
# Match 361: Burnley vs Sheffield United
# Match 362: Sheffield United vs Man City
# Match 363: Sheffield United vs Arsenal
# Match 364: Sheffield United vs Liverpool
# Match 365: Sheffield United vs Aston Villa
# Match 366: Sheffield United vs Tottenham
# Match 367: Sheffield United vs Chelsea
# Match 368: Sheffield United vs Newcastle
# Match 369: Sheffield United vs Man United
# Match 370: Sheffield United vs West Ham
# Match 371: Sheffield United vs Crystal Palace
# Match 372: Sheffield United vs Brighton
# Match 373: Sheffield United vs Bournemouth
# Match 374: Sheffield United vs Fulham
# Match 375: Sheffield United vs Wolves
# Match 376: Sheffield United vs Everton
# Match 377: Sheffield United vs Brentford
# Match 378: Sheffield United vs Nottm Forrest
# Match 379: Sheffield United vs Luton Town
# Match 380: Sheffield United vs Burnley
